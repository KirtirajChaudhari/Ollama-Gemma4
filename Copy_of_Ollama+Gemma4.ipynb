# %% [markdown]
# <a href="https://colab.research.google.com/github/KirtirajChaudhari/Ollama-Gemma4/blob/main/Copy_of_Ollama%2BGemma4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setting Up Ollama on Google Colab and Running Gemma4
#
# ### Installation

# %%
# !sudo apt-get install zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 1s (1,036 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package zstd.
# ...

# %%
#WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# !sudo apt update && sudo apt install pciutils lshw
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,977 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,482 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,310 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %% [markdown]
# ### GPU Enabled

# %%
# !nvidia-smi
# Out:
# Sat Apr  4 04:28:38 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ### Running Ollama Server
#
# Running on a cell leads to getting stuck in that cell, so run it as background process.

# %%
# !ollama serve

# %%
# 1. Kill any existing instances
# !pkill ollama

# 2. Set the environment variable to allow connections
import os
os.environ['OLLAMA_HOST'] = '0.0.0.0:11434'

# 3. Start the server in the background
import subprocess
import time
subprocess.Popen(["ollama", "serve"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# 4. Wait for it to warm up
time.sleep(10)
print("Server should be ready.")
# Out:
# Server should be ready.

# %% [markdown]
# ### Testing if Ollama is Running

# %%
# !curl http://localhost:11434
# Out:
# Ollama is running

# %% [markdown]
# ### Install Ollama Python SDK
#
# It makes using Ollama easy. We can access Ollama programmatically.

# %%
# !pip install ollama

# %% [markdown]
# ### Download Gemma4:e2b Model: Run this on terminal
#
# `ollama pull gemma4:e2b`

# %% [markdown]
# ### Checking Model List In Ollama

# %%
# !ollama list
# Out:
# NAME          ID              SIZE      MODIFIED
# gemma4:e2b    7fbdbf8f5e45    7.2 GB    7 seconds ago

# %% [markdown]
# ### Testing Gemma4 on Text Input

# %%
import ollama
response = ollama.chat(model='gemma4:e2b', messages=[
  {'role': 'user', 'content': 'Why is the sky blue?'},
])
print(response['message']['content'])
# Out:
# The reason the sky appears blue is due to a phenomenon called **Rayleigh scattering**. This is a result of how sunlight interacts with the molecules in the Earth's atmosphere.
#
# Here is a breakdown of the process:
#
# ---
#
# ### 1. Sunlight is Made of Many Colors
#
# Sunlight, which appears white to us, is actually composed of all the colors of the visible spectrum—red, orange, yellow, green, blue, and violet. Each of these colors has a different **wavelength**.
#
# ### 2. Interaction with the Atmosphere
#
# As sunlight travels through the Earth's atmosphere, it collides with the tiny gas molecules, primarily **nitrogen ($N_2$) and oxygen ($O_2$)**.
#
# This collision causes the light to be scattered in different directions.
#
# ### 3. Rayleigh Scattering
#
# ...

# %% [markdown]
# ### Download an Image

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/d/d9/Collage_of_Nine_Dogs.jpg
# Out:
# --2026-04-04 04:36:14--  https://upload.wikimedia.org/wikipedia/commons/d/d9/Collage_of_Nine_Dogs.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.240, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2330812 (2.2M) [image/jpeg]
# Saving to: ‘Collage_of_Nine_Dogs.jpg’
#
# Collage_of_Nine_Dog 100%[===================>]   2.22M  --.-KB/s    in 0.1s
#
# 2026-04-04 04:36:15 (16.3 MB/s) - ‘Collage_of_Nine_Dogs.jpg’ saved [2330812/2330812]

# %% [markdown]
# ### Testing Gemma4 On Image Input

# %%
import base64

# --- How to prepare your image ---
with open("./Collage_of_Nine_Dogs.jpg", "rb") as image_file:
  encoded_image = base64.b64encode(image_file.read()).decode('utf-8')


# Make the call to the model with the image
response = ollama.chat(
    model='gemma4:e2b',
    messages=[
        {
            'role': 'user',
            'content': 'Describe this image.', # content should be a string
            'images': [encoded_image] # images is a list of base64 strings within the message
        }
    ]
)

print(response['message']['content'])
# Out:
# This image is a collage or grid composed of ten separate photographs, all featuring various dogs of different breeds, colors, and textures.
#
# The overall theme of the image is a collection of diverse canine subjects.
#
# Here is a breakdown of the visible elements:
#
# *   **Variety of Dogs:** The collage features dogs ranging in size (from medium to large), coat length (short-haired, long-haired, shaggy), and color (golden, reddish-brown/ginger, cream, dark black).
# *   **Setting:** The backgrounds vary, including grassy areas, dirt, foliage, and wooden surfaces, suggesting they were taken in various outdoor and indoor settings.
# *   **Specific Subjects (Described by panel):**
#     *   Several dogs are lying down, while others are standing.
#     *   One prominent dog in the bottom right corner is a long-haired, dark, fluffy breed.
#     *   Other panels feature dogs with shaggy coats (like the one on the left side) and smooth coats (like the lighter, standing dogs).
#
# ...

# %%
# !nvidia-smi
# Out:
# Sat Apr  4 04:37:52 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   67C    P0             29W /   70W |    7311MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
